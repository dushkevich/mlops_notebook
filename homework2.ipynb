# %%
# !python --version
# Out:
# Python 3.9.7

# %%
# from mlflow.tracking import MlflowClient

# MLFLOW_TRACKING_URI = "sqlite:///mlflow.db"

# client = MlflowClient(tracking_uri=MLFLOW_TRACKING_URI)

# client.search_experiments()

# %%
# !python scripts/preprocess_data.py --raw_data_path data/green-2023 --dest_path ./output

# %%
# !ls output -1 | wc -l
# Out:
# 4

# %%
# !python scripts/train.py --data_path ./output
# Out:
# 2025/10/05 13:15:13 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2025/10/05 13:15:13 INFO mlflow.store.db.utils: Updating database tables
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.

# %%
2
# Out:
# 2

# %%
# !python scripts/hpo.py --data_path ./output
# Out:
# 2025/10/05 14:37:06 INFO mlflow.tracking.fluent: Experiment with name 'random-forest-hyperopt' does not exist. Creating a new experiment.
# 🏃 View run indecisive-cod-609 at: http://127.0.0.1:5000/#/experiments/3/runs/6c89901651ce4e84b1606defac451116
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/3
#
# 🏃 View run nimble-eel-865 at: http://127.0.0.1:5000/#/experiments/3/runs/c42d540bbebd4be7975dce89041edb39
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/3
#
# 🏃 View run polite-kite-421 at: http://127.0.0.1:5000/#/experiments/3/runs/4292456fb64d4c99b73a2b74ebabc76a
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/3
#
# 🏃 View run righteous-steed-950 at: http://127.0.0.1:5000/#/experiments/3/runs/d3e164a6cc534f24a57122de4c0fd3b1
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/3
#
# 🏃 View run wistful-croc-156 at: http://127.0.0.1:5000/#/experiments/3/runs/824c93523ef34c1593aab265aa60de3b
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/3
#
# 🏃 View run delightful-jay-445 at: http://127.0.0.1:5000/#/experiments/3/runs/ba89556504e3463abd625ea91d80edc5
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/3
#
# 🏃 View run chill-lamb-483 at: http://127.0.0.1:5000/#/experiments/3/runs/1a8456dd80164c1ead7337e22a4b7f33
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/3
#
# 🏃 View run worried-cod-544 at: http://127.0.0.1:5000/#/experiments/3/runs/406f7ee7b81b42159ab92df542449846
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/3
#
# 🏃 View run crawling-hen-773 at: http://127.0.0.1:5000/#/experiments/3/runs/2a9f178bd0db45bc968badb914e76b85
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/3
#
# 🏃 View run sneaky-newt-291 at: http://127.0.0.1:5000/#/experiments/3/runs/0ac689eb302a426e83786945c789b87c
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/3
#
# 🏃 View run beautiful-elk-341 at: http://127.0.0.1:5000/#/experiments/3/runs/f23ff9b608184c06ae7cb210d13524f1
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/3
#
# 🏃 View run resilient-stoat-727 at: http://127.0.0.1:5000/#/experiments/3/runs/0c844e20e062468580a28a28535ba9ad
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/3
#
# 🏃 View run nosy-kit-544 at: http://127.0.0.1:5000/#/experiments/3/runs/4cb95398802b4c7da7cdcce3329c479f
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/3
#
# 🏃 View run debonair-slug-145 at: http://127.0.0.1:5000/#/experiments/3/runs/055f8a2299d943cea2a49a42fdf48cb9
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/3
#
# 🏃 View run luxuriant-kite-640 at: http://127.0.0.1:5000/#/experiments/3/runs/8a684c7cea9e4af58c07ca4a3a3c21ae
#
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/3
#
# 100%|██████████| 15/15 [01:05<00:00,  4.37s/trial, best loss: 5.335419588556921]

# %%
# !python scripts/register_model.py --data_path ./output
# Out:
# 🏃 View run silent-grouse-336 at: http://127.0.0.1:5000/#/experiments/4/runs/586b6e9f43a54b6a9128130eaac942e4
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/4
# 🏃 View run indecisive-wasp-582 at: http://127.0.0.1:5000/#/experiments/4/runs/280dc8859aaf42cb8c4129ba989b7276
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/4
# 🏃 View run welcoming-hawk-714 at: http://127.0.0.1:5000/#/experiments/4/runs/82bd9c35f869490d9e89263fe571f32b
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/4
# 🏃 View run unruly-snail-71 at: http://127.0.0.1:5000/#/experiments/4/runs/eb30a30a6c6d42b8a0480ffe454deb17
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/4
# 🏃 View run receptive-shrimp-920 at: http://127.0.0.1:5000/#/experiments/4/runs/17cad1aac65046c29f164df1531ac727
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/4
# Registered model 'best_of_the_best' already exists. Creating a new version of this model...
# 2025/10/05 15:30:52 WARNING mlflow.tracking._model_registry.fluent: Run with id 586b6e9f43a54b6a9128130eaac942e4 has no artifacts at artifact path 'model', registering model based on models:/m-433a389f9db64ae1a7cc294e5fe6570c instead
# 2025/10/05 15:30:52 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: best_of_the_best, version 2
# Created version '2' of model 'best_of_the_best'.
